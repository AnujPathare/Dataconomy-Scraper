# %%
# !pip install selenium
# !pip install requests
# !pip install newspaper3k
# !pip install beautifulsoup4

# %%
import os # python operating system library to deal with OS specific operations
import re # Regex library to manipulate text data
import requests # A library to send HTTP requests to URLs
from newspaper import Article # A python module with which we can 
from bs4 import BeautifulSoup # parse HTML tree structure of a website and used to find information within that HTML
from selenium import webdriver # Selenium is a automation tool, can also be used for web scraping
from selenium.webdriver.common.keys import Keys # used to do keyboard tasks
from selenium.webdriver.common.by import By # 
from selenium.webdriver.chrome.options import Options # Setup driver configurations
from selenium.common.exceptions import NoSuchElementException # an exception in selenium
from selenium.webdriver.common.action_chains import ActionChains # perform chain of actions
import time # used to set time

# %%
options = Options()
options.add_argument("--headless=new")
driver = webdriver.Chrome(options=options)
driver.maximize_window()
driver.get("https://dataconomy.com/")

# %%
blogs_URL = {}
blogs_title_set = {}
blogs_title = {}

# %%
def go_to_category(driver, category_URL):
    
    driver.get(category_URL)

# %%
# category_sub_URLs = ["news", "topics/data-science/artificial-intelligence", "topics/data-science/big-data", "topics/data-science/machine-learning", "tech-trends/blockchain-tech-trends", "cybersecurity", "topics/fintech", "gaming", "topics/internet-of-things", "startups", "industry/energy-environment", "industry/finance", "industry/healthcare", "industry/industrial-goods-and-services", "industry/marketing-sales", "industry/retail-and-consumer-industry", "industry/technology-and-it-industry", "industry/transportation-and-logistics"]

# %%
blogs_URL, blogs_title_set, blogs_title
# Out:
# ({}, {}, {})

# %%
def scrape_blogs(driver, category_sub_URLs, blogs_URL, blogs_title, blogs_title_set):
    

    # first four blogs
    for category_sub_URL in category_sub_URLs:
        go_to_category(driver, f"https://dataconomy.com/category/{category_sub_URL}/")

        for i in range(1,5):

            blog = driver.find_element(By.CLASS_NAME, f'jeg_hero_item_{i}')

            blog_category = blog.find_element(By.CLASS_NAME, 'jeg_post_category').text
            blog_title_tag = blog.find_element(By.CLASS_NAME, 'jeg_post_title')

            if blog_category not in blogs_title:
                blogs_title[blog_category] = []
                blogs_URL[blog_category] = []
                blogs_title_set[blog_category] = set()

            if blog_title_tag.text not in blogs_title_set[blog_category]:

                blogs_title_set[blog_category].add(blog_title_tag.text)
                blogs_title[blog_category].append(blog_title_tag.text)
                blogs_URL[blog_category].append(blog_title_tag.find_element(By.TAG_NAME, 'a').get_attribute("href"))

        page_no = 1

        while True:
            try:
                remaining_blogs = driver.find_elements(By.CLASS_NAME, 'jeg_pl_md_1')

                for blog in remaining_blogs:

                    blog_category = blog.find_element(By.CLASS_NAME, 'jeg_post_category').text
                    blog_title_tag = blog.find_element(By.CLASS_NAME, 'jeg_post_title')

                    if blog_category not in blogs_title:
                        blogs_title[blog_category] = []
                        blogs_URL[blog_category] = []
                        blogs_title_set[blog_category] = set()

                    if blog_title_tag.text not in blogs_title_set[blog_category]:

                        blogs_title_set[blog_category].add(blog_title_tag.text)
                        blogs_title[blog_category].append(blog_title_tag.text)
                        blogs_URL[blog_category].append(blog_title_tag.find_element(By.TAG_NAME, 'a').get_attribute("href"))

                print(f"Page {page_no} over...")
                page_no += 1

                webdriver.ActionChains(driver).send_keys(Keys.END).perform()

                next_page_button = driver.find_element(By.XPATH, "//a[@class='page_nav next']")

                webdriver.ActionChains(driver).move_to_element(next_page_button).click(next_page_button).perform()

            except NoSuchElementException:
                print(f"All Blogs from https://dataconomy.com/category/{category_sub_URL}/ Registered!\n")
                break

# %%
# category_sub_URLs = ["news", "topics/data-science/artificial-intelligence", "topics/data-science/big-data"]
category_sub_URLs = ["topics/data-science/big-data"]
scrape_blogs(driver, category_sub_URLs, blogs_URL, blogs_title, blogs_title_set)
# Out:
# Page 1 over...
# Page 2 over...
# Page 3 over...
# Page 4 over...
# Page 5 over...
# Page 6 over...
# Page 7 over...
# All Blogs from https://dataconomy.com/category/topics/data-science/big-data/ Registered!

# %%
category_sub_URLs = ["topics/data-science/machine-learning", "tech-trends/blockchain-tech-trends", "cybersecurity"]
scrape_blogs(driver, category_sub_URLs, blogs_URL, blogs_title, blogs_title_set)

# %%
category_sub_URLs = ["topics/fintech", "gaming", "topics/internet-of-things"]
scrape_blogs(driver, category_sub_URLs, blogs_URL, blogs_title, blogs_title_set)

# %%
category_sub_URLs = ["startups", "industry/energy-environment", "industry/finance"]
scrape_blogs(driver, category_sub_URLs, blogs_URL, blogs_title, blogs_title_set)

# %%
category_sub_URLs = ["industry/healthcare", "industry/industrial-goods-and-services", "industry/marketing-sales"]
scrape_blogs(driver, category_sub_URLs, blogs_URL, blogs_title, blogs_title_set)

# %%
category_sub_URLs = ["industry/retail-and-consumer-industry", "industry/technology-and-it-industry", "industry/transportation-and-logistics"]
scrape_blogs(driver, category_sub_URLs, blogs_URL, blogs_title, blogs_title_set)

# %%
def save_to_text_file(title, link, author_name, author_URL, date, text, summary, folder_name):
    
    # Remove invalid characters from the title to create a valid filename for the text file
    filename = os.path.join(folder_name, re.sub(r'[\/:*?"<>|]', '', title) + '.txt')

    # Create the directory if it doesn't exist
    os.makedirs(folder_name, exist_ok=True)

    # Open the file in write mode
    with open(filename, 'w', encoding='utf-8') as file:
        # Write the information to the file
        file.write(f'Title: {title}\n\n')
        file.write(f'Article Link: {link}\n\n')
        file.write(f'Author: {author_name}\n\n')
        file.write(f'Publish Date: {date}\n\n')
        file.write(f'Article:\n{text}\n\n')
        file.write(f'Summary: {summary}\n\n')
        file.write(f'Other Blogs by {author_name}: {author_URL}\n')

    print(f'Information saved to {filename}')

# %%
index = 1

for URL_category, urls in blogs_URL.items():
#     total = 0
    for url in urls:
#         total += 1

        print(index, URL_category, url)
        index += 1
# Out:
# 1 BIG DATA https://dataconomy.com/2023/11/10/using-big-data-to-redefine-fc-24-gaming/
# 2 BIG DATA https://dataconomy.com/2023/06/19/what-is-data-deprecation-how-to-prepare/
# 3 BIG DATA https://dataconomy.com/2023/02/23/how-data-engineers-tame-big-data/
# 4 BIG DATA https://dataconomy.com/2022/12/23/what-are-data-silos/
# 5 BIG DATA https://dataconomy.com/2022/09/14/data-in-motion-encryption-security-states/
# 313 BI & ANALYTICS https://dataconomy.com/2014/04/23/massive-analytic/
# 314 NEWS https://dataconomy.com/2022/11/23/tiktok-data-practices-under-investigation/
# 315 NEWS https://dataconomy.com/2022/07/13/ibm-databand-data-observability/
# 316 NEWS https://dataconomy.com/2022/05/06/uk-regulators-algorithmic-processing/
# 317 MACHINE LEARNING https://dataconomy.com/2022/08/05/machine-learning-vs-data-science/
# 318 DATA SCIENCE 101 https://dataconomy.com/2022/08/04/data-governance-framework/
# 319 DATA SCIENCE 101 https://dataconomy.com/2022/04/06/what-is-a-data-mart/
# 320 DATA SCIENCE 101 https://dataconomy.com/2022/04/04/what-is-a-data-dictionary/
# 321 DATA SCIENCE https://dataconomy.com/2022/06/15/23m-funding-datorios-reveals-data-transformation-framework/
# 322 DATA SCIENCE https://dataconomy.com/2022/04/28/artificial-intelligence-in-sports/
# 323 DATA SCIENCE https://dataconomy.com/2022/04/18/data-as-a-service-daas-definition-benefits/
# 324 DATA SCIENCE https://dataconomy.com/2022/03/31/what-is-aggregate-data/
# 325 BLOCKCHAIN https://dataconomy.com/2022/06/01/decentralized-identity-data-blockchain/
# 326 INDUSTRY https://dataconomy.com/2022/05/09/ai-in-manufacturing/
# 327 HEALTHCARE https://dataconomy.com/2022/05/04/future-healthcare-data-security/
# 328 HEALTHCARE https://dataconomy.com/2021/05/05/4-trends-healthcare-digital-transformation-2021/
# 329 CONVERSATIONS https://dataconomy.com/2022/04/13/how-to-use-real-time-data-to-scale/
# 330 TECHNOLOGY & IT https://dataconomy.com/2022/04/07/fog-computing-definition-origins-benefits/
# 331 TECHNOLOGY & IT https://dataconomy.com/2021/08/31/storage-video-surveillance-keep-it-simple/
# 332 TECHNOLOGY & IT https://dataconomy.com/2021/04/20/western-digital-ssd-free-raidix-era-license-saves-drives-costs/
# 333 TOPICS https://dataconomy.com/2022/03/11/how-tech-changes-enterprise-risk-management/
# 334 FINANCE https://dataconomy.com/2021/10/29/how-data-science-helps-insurance-companies/
# 335 FINANCE https://dataconomy.com/2021/06/30/future-predictive-analytics-insurance-industry/
# 336 CONTRIBUTORS https://dataconomy.com/2021/09/03/why-moving-data-so-expensive/

# %%
for URL_category, url_list in blogs_URL.items():
    for url in url_list:

        time.sleep(5)

        # Make a request to the URL
        response = requests.get(url)
        html = response.text

        # Use BeautifulSoup to parse the HTML
        soup = BeautifulSoup(html, 'html.parser')

        # Find author information
        author = soup.find('div', class_='jeg_meta_author').find('a')

        # Create an Article object
        article = Article(url)
        article.set_html(html)
        article.parse()
        article.nlp()

        # Extract information from the article
        title = article.title

        filename = os.path.join(URL_category, re.sub(r'[\/:*?"<>|]', '', title) + '.txt')
        # Check if the file already exists
        if os.path.exists(filename):
            print(f'File {filename} already exists. Skipping...')
            continue
        
        # Extract information from the article
        link = article.url
        author_name = author.text
        author_URL = author.get('href')
        date = article.publish_date.date()
        text = article.text
        summary = article.summary

        # Save information to a text file in the respective folder
        save_to_text_file(title, link, author_name, author_URL, date, text, summary, URL_category)
# Out:
# Information saved to BIG DATA\Using big data to redefine FC 24 gaming.txt
# Information saved to BIG DATA\Your online personal data has a guardian angel.txt
# Information saved to BIG DATA\How data engineers tame Big Data.txt
# Information saved to BIG DATA\Data silos are the silent killers of business efficiency.txt
# Information saved to BIG DATA\Enterprises, caution your “data in motion”.txt
# Information saved to BIG DATA\Everything you should know about big data services.txt
# Information saved to BIG DATA\The ABC’s of data transformation.txt
# Information saved to BIG DATA\The key of optimization Data points.txt
# Information saved to BIG DATA\Data lifecycle management Framework, goals, and challenges (2022).txt
# Information saved to BIG DATA\What makes a computer “super”.txt
# Information saved to BIG DATA\Data democratization is not a walk in the park, but you still need it anyway.txt
# Information saved to BIG DATA\Bottomless Storage and Pipeline The Quest for a New Database Paradigm.txt
# Information saved to BIG DATA\Curate your big data to unleash its power.txt
# Information saved to BIG DATA\4 techniques to utilize data profiling for data quality evaluation.txt
# Information saved to BIG DATA\How does the hybrid cloud offer the best of both worlds.txt
# Information saved to BIG DATA\Data modeling A blueprint for valuable database.txt
# Information saved to BIG DATA\How to unlock the value of data by using metadata.txt
# Information saved to BIG DATA\Where do data silos come from, and why are they a problem.txt
# Information saved to BIG DATA\SMEs can benefit from Big Data just like an enterprise.txt
# Information saved to BIG DATA\Enterprise data sovereignty is the latest trend, so what is it.txt
# Information saved to BIG DATA\The 7 Cooperative Principles and Why They’re Critical to Data Sovereignty.txt
# Information saved to BIG DATA\In conversation the Chaos Computer Club, transparency, and data income plans.txt
# Information saved to BIG DATA\Top 6 trends in data analytics for 2022.txt
# Information saved to BIG DATA\Harnessing Time and Space Data Is a Major Market Opportunity if It Doesn’t Crush You First.txt
# Information saved to BIG DATA\5 Big Data Disruptions Coming in 2022.txt
# Information saved to BIG DATA\How vectorization is helping identify UFOs, UAPs, and whether aliens are responsible.txt
# Information saved to BIG DATA\Combating infobesity with smaller data ‘bytes’.txt
# Information saved to BIG DATA\The data lakehouse just another crazy buzzword.txt
# Information saved to BIG DATA\Open and free online data collection will fuel future innovations.txt
# Information saved to BIG DATA\Three Trends in Data Science Jobs You Should Know.txt
# Information saved to BIG DATA\Here are the Sweet Spots for Alternative Web Data in 2020.txt
# Information saved to BIG DATA\Search vs. Discovery How Are They Different.txt
# Information saved to BIG DATA\Why Businesses Should Turn to Data to Fight Climate Change.txt
# Information saved to BIG DATA\Consumer data might be the new oil, but who gets to decide how it’s used.txt
# Information saved to BIG DATA\Three Critical Aspects of Design Thinking for Big Data Solutions.txt
# Information saved to BIG DATA\Distributed Data Caching Using Big Data.txt
# Information saved to BIG DATA\How Big Data Assists in Disaster Relief and Preparedness.txt
# Information saved to BIG DATA\Kubernetes Meets Big Data.txt
# Information saved to BIG DATA\Three questions you need to answer to succeed in data-driven projects.txt
# Information saved to BIG DATA\What can data-driven startups gain from Ruhrgebiet region in Europe.txt
# Information saved to BIG DATA\16 Best Big Data Programs at Prestigious MBA Schools.txt
# Information saved to BIG DATA\Who should own data analytics in your company and why.txt
# Information saved to BIG DATA\Four Data Challenges Posed by the Connected Car.txt
# Information saved to BIG DATA\Why Business Schools Need to Think About Offering Education in Big Data.txt
# Information saved to BIG DATA\Here is everything you want to know about Sports Analytics.txt
# Information saved to BIG DATA\Blockchain Technology Will Revolutionize These Five Industries.txt
# Information saved to BIG DATA\Why object storage must be part of your data strategy in 2018.txt
# Information saved to BIG DATA\Four Big Reasons Why Enterprises are Embracing Object Storage.txt
# Information saved to BIG DATA\Why Edge Security is the Way of the Future.txt
# Information saved to BIG DATA\Six reasons to think twice about your data lake strategy.txt
# Information saved to BIG DATA\Five Careers to Consider for Data Enthusiasts.txt
# Information saved to BIG DATA\Blockchain Found a Shortcut to the Universal Sharing Economy.txt
# Information saved to BIG DATA\To Avoid Cyberattacks, You Must Clean Your Data. Here’s Why..txt
# Information saved to BIG DATA\How Germany’s BDSG-neu Will Impact Mobile Data Collection.txt
# Information saved to BIG DATA\Hadoop Evolved How Industries Are Being Transformed By Big Data.txt
# Information saved to BIG DATA\Can Data Analytics Elevate Soccer’s Profile in the U.S..txt
# Information saved to BIG DATA\Do You Have the Expertise to be a Big Data Project Manager.txt
# Information saved to BIG DATA\It’s Tax Season How Big Data Is Transforming The Filing Process.txt
# Information saved to BIG DATA\How GDPR Will Affect Data Science.txt
# Information saved to BIG DATA\The Role of Big Data and Mobile Apps in Healthcare.txt
# Information saved to BIG DATA\Frictionless Data Why Ease and Portability Are More Important Than Ever.txt
# Information saved to BIG DATA\How Data Exhaust Can Be Leveraged To Benefit Your Company.txt
# Information saved to BIG DATA\10 Tips for Avoiding an Alternative Data Hangover.txt
# Information saved to BIG DATA\Getting Your Feet Muddy with Data Science A Conversation with Ross Taylor.txt
# Information saved to BIG DATA\INFOGRAPHIC How Netflix Uses Big Data to Drive Success.txt
# Information saved to BIG DATA\Big data basics for tech beginners.txt
# Information saved to BIG DATA\How Big Data Is Revolutionizing Sports.txt
# Information saved to BIG DATA\Blockchain and Data Storage The Future is Decentralized.txt
# Information saved to BIG DATA\Random Data Explained Harnessing the Benefits of TRNGs and PRNGs.txt
# Information saved to BIG DATA\Control Data Variety with an Enterprise Data Fabric.txt
# Information saved to BIG DATA\How to best Leverage the Services of Hadoop Big Data.txt
# Information saved to BIG DATA\4 Insights on the future of data centers.txt
# Information saved to BIG DATA\When Data Science Alone Won’t Cut it.txt
# Information saved to BIG DATA\Unlock the Cloud’s Potential Security Tools and Best Practices.txt
# Information saved to BIG DATA\What if companies managed their data as carefully as they manage their money.txt
# Information saved to BIG DATA\Cloud adoption on the rise for marketing and sales companies as AWS and Azure dominate.txt
# Information saved to BIG DATA\GDPR and the skills gap that could cost you €20million.txt
# Information saved to BIG DATA\Improving Employee Management using Big Data.txt
# Information saved to BIG DATA\What makes organizations successful with data.txt
# Information saved to BIG DATA\5 Ways The Healthcare Industry Could Use Big Data—and Why It’s Not.txt
# Information saved to BIG DATA\High Performance Big Data Analysis Using NumPy, Numba & Python Asynchronous Programming.txt
# Information saved to BIG DATA\10 Challenges to Big Data Security and Privacy.txt
# Information saved to BIG DATA\The Impact of Big Data on Banking and Financial Systems.txt
# Information saved to BIG DATA\75 Big Data terms everyone should know.txt
# Information saved to BIG DATA\Three signs you might be experiencing a NoSQL hangover.txt
# Information saved to BIG DATA\Disaster recovery plan essential under GDPR.txt
# Information saved to BIG DATA\6 Ways to Use Big Data in Ecommerce.txt
# Information saved to BIG DATA\What is really driving public opinion – The next level in data analytics.txt
# Information saved to BIG DATA\Big Data’s Potential For Disruptive Innovation.txt
# Information saved to BIG DATA\Winning with Data Science, Golden State Warriors Style.txt
# Information saved to BIG DATA\How To Stop Data Breaches From Ruining Your Business.txt
# Information saved to BIG DATA\How Data & IoT Technology are Changing The Way We Travel.txt
# Information saved to BIG DATA\Big Data Is Revolutionizing The Way We Develop Life-Saving Medicine.txt
# Information saved to BIG DATA\The Data Ecosystem Taking a Cloud-First approach to IT.txt
# Information saved to BIG DATA\Big Data in Real Estate Staying Ahead of the Curve.txt
# Information saved to BIG DATA\Amazon Kinesis vs. Apache Kafka For Big Data Analysis.txt
# Information saved to BIG DATA\Dare to Share in The Cloud How Secure Is Your Data.txt
# Information saved to BIG DATA\Big Data for Humans The Importance of Data Visualization.txt
# Information saved to BIG DATA\Big Data 101 Intro To Probabilistic Data Structures.txt
# Information saved to BIG DATA\The 5 Best Reasons to Choose MySQL – and its 5 Biggest Challenges.txt
# Information saved to BIG DATA\Big Data Symbiosis Using Lessons from Big Data to Protect Big Data.txt
# Information saved to BIG DATA\Using Data To Build Better Online User Experiences.txt
# Information saved to BIG DATA\Data Science vs. Data Analytics – Why Does It Matter.txt
# Information saved to BIG DATA\The 3 Reasons Why Companies Should Use HPC.txt
# Information saved to BIG DATA\25 Big Data Terms Everyone Should Know.txt
# Information saved to BIG DATA\The Power of a Data Value Chain For Your Business.txt
# Information saved to BIG DATA\Stream Processing Myths Debunked.txt
# Information saved to BIG DATA\2017 – The Year Data Made Bank.txt
# Information saved to BIG DATA\Data Mining for Predictive Social Network Analysis.txt
# Information saved to BIG DATA\How to Build a Data Strategy Pt. II – The 4 Step Process.txt
# Information saved to BIG DATA\How to avoid the 7 most common mistakes of Big Data analysis.txt
# Information saved to BIG DATA\How To Build a Data Strategy Pt. I – Your Ticket to Success.txt
# Information saved to BIG DATA\Using Data to Discover Hidden Value in Your Customer Journey.txt
# Information saved to BIG DATA\What is Metadata and why is it as important as the data itself.txt
# Information saved to BIG DATA\A Big Market For Big Data – An Outlook on 2017.txt
# Information saved to BIG DATA\3 Things Every Business Needs to know About Second-Party Data Sharing.txt
# Information saved to BIG DATA\“Before big data and all the buzzwords, it was all data mining” – Kathleen Kennedy, MIT Technology Review.txt
# Information saved to BIG DATA\Data Transparency Could Fix Digital Marketing.txt
# Information saved to BIG DATA\7 Signs You Should Move to Big Data Storage.txt
# Information saved to BIG DATA\How-To Migrate A Database from On-Premise to the Cloud.txt
# Information saved to BIG DATA\Driving Value with Data Science.txt
# Information saved to BIG DATA\How Organizations Build Back-Ends for Big Data.txt
# Information saved to BIG DATA\Turning Big Data from Cost to Revenue.txt
# Information saved to BIG DATA\How Big Data Can Improve Student Performance and Learning Approaches.txt
# Information saved to BIG DATA\“Finding a relevant, trustworthy dataset can be like finding a needle in a haystack” – Interview with Satyen Sangani.txt
# Information saved to BIG DATA\Are We Not Data-Driven Fact, Myth and Populism in Analytical Cultures.txt
# Information saved to BIG DATA\Getting Off to a Great Start in Your Big Data Career.txt
# Information saved to BIG DATA\Call for Startups Announcing Data Natives Tel Aviv’s “Startup Battle”.txt
# Information saved to BIG DATA\Q&A with Big Data Thought Leader, Ami Gal – Data Natives Tel Aviv 2016.txt
# Information saved to BIG DATA\Are CEO’s Missing out on Big Data’s Big Picture.txt
# Information saved to BIG DATA\Q&A With MapR’s Crystal Valentine – Data Natives Tel Aviv 2016.txt
# Information saved to BIG DATA\Pokémon Go and Big Data You Teach Me and I’ll Teach You.txt
# Information saved to BIG DATA\Big Data is Transforming Commercial Construction.txt
# Information saved to BIG DATA\From Shelter to Forever Home, Big Data Helps Pets.txt
# Information saved to BIG DATA\What Real Time Streaming Means for Big Data.txt
# Information saved to BIG DATA\Big Data Bets on the Online Casino Industry.txt
# Information saved to BIG DATA\Here is a New Resource for Your Organization and it’s called Big Data!.txt
# Information saved to BIG DATA\Professional Sports Get Makeover From Big Data.txt
# Information saved to BIG DATA\The Future of Big Data Is Open Source.txt
# Information saved to BIG DATA\Three Times Big Data Made Amusement Parks Better.txt
# Information saved to BIG DATA\Big Data Plays Surprising Role In Fight Against Climate Change.txt
# Information saved to BIG DATA\The Growing use of Big Data at Intelligence Agencies.txt
# Information saved to BIG DATA\Big Data isn’t the problem – data copies are.txt
# Information saved to BIG DATA\Three Unexpected Uses for 3D Printing in Big Data.txt
# Information saved to BIG DATA\Big Data’s Next Big Impact Oil & Gas.txt
# Information saved to BIG DATA\Can Big Data Help Us Travel Better.txt
# Information saved to BIG DATA\“A great deal of tech challenges in our industry are ultimately challenges in understanding people.”-Interview with Quantcast’s Peter Sirota.txt
# Information saved to BIG DATA\The Data Is In 3 Ways Analytics Will Improve Healthcare.txt
# Information saved to BIG DATA\Big Data Reveals Big Gender Inequality.txt
# Information saved to BIG DATA\Hadoop and Spark A Match Made in (Big Data) Heaven.txt
# Information saved to BIG DATA\Clinton-Sanders Data Breach Highlights Power of Big Data in Politics.txt
# Information saved to BIG DATA\What kind of industries will expand their use of fast data in 2016.txt
# Information saved to BIG DATA\Data Tracking In The Workplace Is Big Data Hurting Employees.txt
# Information saved to BIG DATA\Taking a bite into Big Data.txt
# Information saved to BIG DATA\Can Big Data Save Your Love Life Online Dating Apps Say “Yes”.txt
# Information saved to BIG DATA\Big Data and the Optimisation of Labour.txt
# Information saved to BIG DATA\Data is the New Dollar Turning Data Into Business Profit.txt
# Information saved to BIG DATA\Internet of Aircraft Things How Analytics of IoAT is transforming the aerospace industry.txt
# Information saved to BIG DATA\How Big Data Is Quietly Fighting Diseases and Illnesses.txt
# Information saved to BIG DATA\Removing the Human Element from Big Data Analytics.txt
# Information saved to BIG DATA\Will Big Data Write The Next Hit Song.txt
# Information saved to BIG DATA\“Knowledge of the business really influences how one approaches analyzing issues”-Interview with MineThatData’s Kevin Hillstrom.txt
# Information saved to BIG DATA\“I don’t think that you should approach big data as a solution in search of a problem”- Interview with Skimlinks Maria Mestre.txt
# Information saved to BIG DATA\How Data Science Is Driving The Driverless Car.txt
# Information saved to BIG DATA\Have a Data-Appropriate Christmas Big Data, Big Companies and Santa.txt
# Information saved to BIG DATA\“To avoid losing great people, they need to be developing all the time.” – Interview with GoCardlesses Natalie Hockham.txt
# Information saved to BIG DATA\“Open source and public cloud are the most impactful shifts I have seen.” – Interview with Google Cloud Platform’s William Vambenepe.txt
# Information saved to BIG DATA\Around Europe in 8 Big Data Start­ups.txt
# Information saved to BIG DATA\“Write a ton of code. Don’t watch TV. ” – An Interview with Data Scientist Erik Bernhardsson.txt
# Information saved to BIG DATA\Improving the Accuracy of Big Data Analysis.txt
# Information saved to BIG DATA\Big Data Solutions for Small Businesses.txt
# Information saved to BIG DATA\6 Keys to Big Data Victory.txt
# Information saved to BIG DATA\IoT, Big Data And Preventative Predictions.txt
# Information saved to BIG DATA\The 7 Most Unusual Applications of Big Data.txt
# Information saved to BIG DATA\5 Amazing Companies That Really Get Big Data.txt
# Information saved to BIG DATA\Bank of England’s Advisory Panel Believes Big Data Can Help Cull Illegal Trader Practices.txt
# Information saved to BIG DATA\Going Where Big Data Has Never Gone Before….txt
# Information saved to BIG DATA\Ford Focuses on Big Data Ambitions with the New Silicon Valley Research Centre.txt
# Information saved to BIG DATA\How Big Data Can Help in the Fight to Save India’s Tigers.txt
# Information saved to BIG DATA\Big Data to Curb the Menace of Human Trafficking and Prostitution.txt
# Information saved to BIG DATA\Social Media is Dead. Big Data is on Life Support..txt
# Information saved to BIG DATA\UK Political Parties Tap into Big Data Analytics in the Elections Race.txt
# Information saved to BIG DATA\Big Data The Bridge to Success.txt
# Information saved to BIG DATA\8 Trends In Big Data For 2015.txt
# Information saved to BIG DATA\The NHS A&E Crisis and a Big Data Solution.txt
# Information saved to BIG DATA\Huawei Tech Chief Discloses Company’s Big Data, IoT Expansion Strategy for the Future.txt
# Information saved to BIG DATA\Furthering its Big Data and IoT Cause, UK Govt. Releases Study to Chart Out Recommendations for the Future.txt
# Information saved to BIG DATA\Big Data Food Tech Innovator Hampton Creek Scoops Up $90M in Series C, with Plans to Expand and Develop R&D.txt
# Information saved to BIG DATA\Marine Scientists at Oregon State University Will Harness Big Data to Catalogue Data on Sea Life.txt
# Information saved to BIG DATA\Malaysian ICT Custodian Reveals the Setting in Motion of the Country’s Big Data Framework.txt
# Information saved to BIG DATA\GE, Cisco Orchestrate Plans to Provide Big Data Services to the Enterprise.txt
# Information saved to BIG DATA\Top 14 Big Data Books of 2014.txt
# Information saved to BIG DATA\This Comic Can Help Us Understand Our Place in the World of Big Data.txt
# Information saved to BIG DATA\Travel Startup Hopper Uses Big Data to Find Cheaper Travel Options for Users.txt
# Information saved to BIG DATA\Indian Government Using Big Data to Revolutionise Democracy.txt
# Information saved to BIG DATA\Telit Launches First Big Data Challenge in Collaboration with Google Cloud Platform.txt
# Information saved to BIG DATA\Skillsoft’s Big Data Initiative Delivers Improved Learning Engagement and Outcomes.txt
# Information saved to BIG DATA\Formula One Wins Riding on Big Data Analysis.txt
# Information saved to BIG DATA\How Big Data Is Changing The Insurance Industry Forever.txt
# Information saved to BIG DATA\Visual Cues in Big Data for Analytics and Discovery.txt
# Information saved to BIG DATA\STFC Partners with IBM to Create Infosphere BigInsights, the Tech Giant’s New Big Data Innovation Hub.txt
# Information saved to BIG DATA\Microsoft ‘Brings Big data to Everyone’ with Latest Azure Machine Learning Update – Makes it Accessible Free of Cost.txt
# Information saved to BIG DATA\NVP’s Big Data Executive Survey 2014 Highlights Forces Driving Business Investment in Big Data.txt
# Information saved to BIG DATA\Top Tips for Implementing a Big Data Strategy.txt
# Information saved to BIG DATA\Big Data Jobs Earn 24% More Than Other IT Positions, New Study Reveals.txt
# Information saved to BIG DATA\Big Data Evolves Into a Formidable Driving Force Behind US Election Campaigns.txt
# Information saved to BIG DATA\Australian Organisations Are Disenchanted By Big Data.txt
# Information saved to BIG DATA\Next Up for Big Data – Ice Hockey and Game Play Analytics.txt
# Information saved to BIG DATA\NIH Releases $32M Strong Support Towards Development in Biomedical Fields Tapping Big Data.txt
# Information saved to BIG DATA\Data Scientists in UK Risk Crumbling Under Mounting Stress as Big Data Industry Thrives.txt
# Information saved to BIG DATA\US National Science Foundation Funds $31m Boost to Big Data Infrastructure.txt
# Information saved to BIG DATA\Global Forest Watch Taps Big Data to Prevent Deforestation – Setting Precedent for Climate Change Reversal Initiatives.txt
# Information saved to BIG DATA\How Big Data Can Boost Equality of Opportunity in Education.txt
# Information saved to BIG DATA\What the Future Holds for the Internet of Things & Smart Cities.txt
# Information saved to BIG DATA\Western Europe Committed to Close Big Data Utilization Gap.txt
# Information saved to BIG DATA\How Big Data at the U.S. Open is Changing the Fan Experience.txt
# Information saved to BIG DATA\Gartner Study Shows that Global Investment in Big Data Is Set to Increase Again.txt
# Information saved to BIG DATA\Amazon See How Big Data Can Drive Business Success.txt
# Information saved to BIG DATA\C-level Executives Reaping the Benefits of Big Data, Accenture Study Finds.txt
# Information saved to BIG DATA\Toshiba and Johns Hopkins University Partner to Use Big Data in Healthcare Research.txt
# Information saved to BIG DATA\Big Data Won’t Prevent the “Next Ferguson”- But It Might Stop the Tragedy After That.txt
# Information saved to BIG DATA\U.K. Trails Behind Neighbours France and Germany in Exploiting Big Data According to Recent Survey.txt
# Information saved to BIG DATA\Baidu and UN Development Programme to Utilise Big Data to Solve Environmental Issues.txt
# Information saved to BIG DATA\U.S. SEC Taps into Big Data and Cloud Computing to Make Big Savings and Enhance Prospects.txt
# Information saved to BIG DATA\Big Data Reveals the Smartest Have Been Magnetised to the Cities for 2,000 Years.txt
# Information saved to BIG DATA\US Attorney General Raises Concerns About Big Data in Criminal Justice.txt
# Information saved to BIG DATA\How Utilities Are Wrestling with Big Data…And Winning.txt
# Information saved to BIG DATA\How big data is being used to solve Chicago’s rat problem.txt
# Information saved to BIG DATA\Big Data’s Diminishing the Organ Transplant Waitlist.txt
# Information saved to BIG DATA\Bitcoin and Big Data Can We Predict the Future Value of Virtual Currency.txt
# Information saved to BIG DATA\KPMG and Imperial College Aim to Harness the Power of Big Data.txt
# Information saved to BIG DATA\Big Data at Oxford University, with Professor Eric T. Meyer.txt
# Information saved to BIG DATA\Big Data & Archaeology Peering into Lost Worlds.txt
# Information saved to BIG DATA\How IBM Will Use Big Data to Help China’s War on Pollution.txt
# Information saved to BIG DATA\Turning Big Data into Defence Strategies- the D2D CRC Launces.txt
# Information saved to BIG DATA\“The Array of Things” Chicago Implements City-Wide Big Data Project.txt
# Information saved to BIG DATA\Big Data is Making America’s Food Safer.txt
# Information saved to BIG DATA\Chicago Improving City Life with Big Data.txt
# Information saved to BIG DATA\Wells Fargo Open Big Data Lab.txt
# Information saved to BIG DATA\US Military Using Big Data to Improve Situational Awareness.txt
# Information saved to BIG DATA\Using Big Data in the Fight Against Extinction.txt
# Information saved to BIG DATA\Big Data Saving Lives Pioneering Blood Cancer Research.txt
# Information saved to BIG DATA\Western Union Fights Wire Transfer Fraud With Big Data.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Databases are the unsung heroes of AI.txt
# Information saved to ARTIFICIAL INTELLIGENCE\How AI and big data analytics are changing influencer marketing.txt
# Information saved to ARTIFICIAL INTELLIGENCE\AI and big data are the driving forces behind Industry 4.0.txt
# Information saved to ARTIFICIAL INTELLIGENCE\The insurance of insurers.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Data science certifications that can give you an edge.txt
# Information saved to ARTIFICIAL INTELLIGENCE\How to put AI to work in your company.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Europe’s largest data science community launches the digital network platform for this year’s conference.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Data acquisition in 6 easy steps.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Three Steps to Using Sensitive Data for Facilitating M&A Scenarios.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Hackathons and action groups how tech is responding to the COVID-19 pandemic.txt
# Information saved to ARTIFICIAL INTELLIGENCE\How Coronavirus can make open-source movements flourish and fix our healthcare systems.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Key Challenges That Healthcare AI Needs to Overcome in 2020.txt
# Information saved to ARTIFICIAL INTELLIGENCE\How to advance in your data science career – AMA with Elena Poughia.txt
# Information saved to ARTIFICIAL INTELLIGENCE\HackCorona 300 participants, 41 nationalities, 23 solutions to fight COVID-19 outbreak.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Why Data Scientists Must Be Able to Explain Their Algorithms.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Thriving SaaS Growth and Containerization Use Will Drive Cloud Market in 2020.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Why over one-third of AI and Analytics Projects in the Cloud fail.txt
# Information saved to ARTIFICIAL INTELLIGENCE\2020 The Decade of Intelligent, Democratized Data.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Picks on AI trends from Data Natives 2019.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Five Ways to Make Better Data-Driven Decisions in 2020.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Why 96% of Enterprises Face AI Training Data Issues.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Can Big Data Help Provide Affordable Healthcare.txt
# Information saved to ARTIFICIAL INTELLIGENCE\It’s a Wrap Highlights from Data Natives 2018.txt
# Information saved to ARTIFICIAL INTELLIGENCE\How Effective Is AI Crime Prediction Evaluating Our London Crime Prediction Model.txt
# Information saved to ARTIFICIAL INTELLIGENCE\15 GLOBAL INFLUENCERS IN ARTIFICIAL INTELLIGENCE AND MACHINE LEARNING.txt
# Information saved to ARTIFICIAL INTELLIGENCE\First Speakers Announced for Data Natives 2018, The Tech Conference of the Future.txt
# Information saved to ARTIFICIAL INTELLIGENCE\HOW HEALTH TECH STARTUPS USE BIG DATA AND AI TO TRANSFORM DIABETES CARE IN 2018.txt
# Information saved to ARTIFICIAL INTELLIGENCE\How Is Data Science Transforming Web Development.txt
# Information saved to ARTIFICIAL INTELLIGENCE\Bringing Artificial Intelligence to the Rail Industry.txt
# Information saved to BI & ANALYTICS\Elevating business decisions from gut feelings to data-driven excellence.txt
# Information saved to BI & ANALYTICS\Sneak peek at Microsoft Fabric price and its promising features.txt
# Information saved to BI & ANALYTICS\Business processes need data management for their continuous improvement.txt
# Information saved to BI & ANALYTICS\Break down management or governance difficulties by data integration.txt
# Information saved to BI & ANALYTICS\6 best data governance practices.txt
# Information saved to BI & ANALYTICS\How to improve your data quality in four steps.txt
# Information saved to BI & ANALYTICS\Data cleaning time has come Make your business clearer.txt
# Information saved to BI & ANALYTICS\Infuse Analytics to Empower Decision Making throughout Your Organization.txt
# Information saved to BI & ANALYTICS\How to choose the right data stack for your business.txt
# Information saved to BI & ANALYTICS\How to make data lakes reliable.txt
# Information saved to BI & ANALYTICS\Bracing for Brexit Best Practices for Data Migration in Wake of 2020 Brexit.txt
# Information saved to BI & ANALYTICS\C-Suite Whispers Considering an event-centric data strategy Here’s what you need to know.txt
# Information saved to BI & ANALYTICS\Lessons from the Basketball Court for Data Management.txt
# Information saved to BI & ANALYTICS\Bridging the CDO talent gap Top Three skills a CDO needs.txt
# Information saved to BI & ANALYTICS\Not All Pregnancies Count The Data Gap on Maternal Health and Jails.txt
# Information saved to BI & ANALYTICS\A Data Scientist’s relationship with building Predictive Models.txt
# Information saved to BI & ANALYTICS\Data’s Growing Role in Scalable Ecommerce​.txt
# Information saved to BI & ANALYTICS\Behavioral Science Shapes Data Science and Drives Change.txt
# Information saved to BI & ANALYTICS\How to monetize your data in the right way.txt
# Information saved to BI & ANALYTICS\Six Biggest Recent Data Breaches You’ve Probably Been Affected By.txt
# Information saved to BI & ANALYTICS\Five Ways Data Is Assisting the Construction & Civil Engineering Industry.txt
# Information saved to BI & ANALYTICS\How GDPR is Affecting Marketing Data.txt
# Information saved to BI & ANALYTICS\How Blockchain Can Supercharge the Network Effect.txt
# Information saved to BI & ANALYTICS\Four Data Analytics Pitfalls and How to Avoid Them.txt
# Information saved to BI & ANALYTICS\The Rise of 5G A Culture Shift in Data Analytics.txt
# Information saved to BI & ANALYTICS\How GDPR can affect your company brand.txt
# Information saved to BI & ANALYTICS\5 Ways Big Data and Analytics Will Impact E-Commerce in 2018.txt
# Information saved to BI & ANALYTICS\4 data-driven ways to digitize your business.txt
# Information saved to BI & ANALYTICS\Four Strategic Differentiators of an Enterprise Knowledge Graph.txt
# Information saved to BI & ANALYTICS\Steering Big Data Projects in the Modern Enterprise.txt
# Information saved to BI & ANALYTICS\Big Data is changing the future of NBA scouting.txt
# Information saved to BI & ANALYTICS\Data Nirvana – How to develop a data-driven culture.txt
# Information saved to BI & ANALYTICS\Data Mining for Social Intelligence – Opinion data as a monetizable resource.txt
# Information saved to BI & ANALYTICS\The Data Pipeline – Analytics at the Speed of Business.txt
# Information saved to BI & ANALYTICS\Seizing Opportunities with Data-as-a-Service Products.txt
# Information saved to BI & ANALYTICS\Corporate Self Service Analytics 4 Questions You Should Ask Yourself Before You Start.txt
# Information saved to BI & ANALYTICS\Turning Big Data Disillusionment into an Opportunity with Data-as-a-Service Products.txt
# Information saved to BI & ANALYTICS\“Companies are finally able to start a data culture” – Interview with Frank Bien, CEO of Looker.txt
# Information saved to BI & ANALYTICS\Thinking About Cloud Data Analytics Consider This.txt
# Information saved to BI & ANALYTICS\Top 5 Big Data Merger and Acquisition Trends in 2014.txt
# Information saved to BI & ANALYTICS\Massive Analytic – Big Data, Decisions and Outcomes.txt
# Information saved to NEWS\EU probes TikTok’s data practices with multiple investigations.txt
# Information saved to NEWS\IBM acquires Databand to boost data observability.txt
# Information saved to NEWS\UK regulators are calling for views on algorithmic processing and auditing.txt
# Information saved to MACHINE LEARNING\Machine learning makes life easier for data scientists.txt
# Information saved to DATA SCIENCE 101\The data governance framework is an indispensable compass of the digital age.txt
# Information saved to DATA SCIENCE 101\How to organize your company’s vital data using a data mart to identify its key findings.txt
# Information saved to DATA SCIENCE 101\Can a data dictionary will lead the road to successful database management.txt
# Information saved to DATA SCIENCE\After $23m in funding, Datorios reveals its data transformation framework in Vegas.txt
# Information saved to DATA SCIENCE\AI & Big Data are changing the sports for good.txt
# Information saved to DATA SCIENCE\When will DaaS get its big break.txt
# Information saved to DATA SCIENCE\What role does aggregate data play in a business’s success.txt
# Information saved to BLOCKCHAIN\Decentralized identity data through blockchain technology.txt
# Information saved to INDUSTRY\AI in manufacturing The future of Industry 4.0.txt
# Information saved to HEALTHCARE\What is the future of healthcare data security.txt
# Information saved to HEALTHCARE\4 Trends Driving Healthcare’s Digital Transformation in 2021.txt
# Information saved to CONVERSATIONS\Chris Latimer tells how to use real-time data to scale and perform better.txt
# Information saved to TECHNOLOGY & IT\Is fog computing more than just another branding for edge computing.txt
# Information saved to TECHNOLOGY & IT\Storage for video surveillance keep it simple.txt
# Information saved to TECHNOLOGY & IT\Western Digital Ultrastar SN640 NVMe SSD equipped with RAIDIX ERA software ensures high performance and fault-tolerance – tests confirm.txt
# Information saved to TOPICS\How technology changes Enterprise Risk Management.txt
# Information saved to FINANCE\How Data Science Helps Insurance Companies Manage Losses and Protect Customers.txt
# Information saved to FINANCE\The Future of Predictive Analytics In the Insurance Industry.txt
# Information saved to CONTRIBUTORS\Why Is Moving Data So Expensive.txt
